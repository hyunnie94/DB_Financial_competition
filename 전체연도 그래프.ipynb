# %%
import seaborn as sns
import numpy as np
import pandas as pd
from pandas import DataFrame as df
from pandas import Series
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy.stats as sp
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
import sys
rc('font', family=font_name)
# %matplotlib inline

# %%
d1 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\1983~2018 전체.csv", delimiter=',', engine="python")
d2 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\1983~2018 남자.csv", delimiter=',', engine="python")
d3 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\1983~2018 여자.csv", delimiter=',', engine="python")

# %%
d1
# Out:
#                                     사망원인별(103항목)   1983   1984   1985   1986  \
# 0                     특정 감염성 및 기생충성 질환 (A00-B99)  10560   9672   8551   7690
# 1                                  신생물 (C00-D48)  29384  29872  32055  33201
# 2   혈액 및 조혈기관질환과 면역메커니즘을 침범하는 특정장애 (D50-D89) (명)    308    300    300    296
# 3                      내분비, 영양 및 대사 질환 (E00-E88)   2432   2821   3042   3274
# 4                            정신 및 행동장애 (F01-F99)   1317   1425   1384   1393
# 5                             신경계통의 질환 (G00-G98)   3067   2626   2423   2308
# 6                         눈 및 눈부속기의 질환 (H00-H57)     16     16      8      5
# 7                           귀 및 유돌의 질환 (H60-H93)      9      8      7      4
# 8                              순환계통 질환 (I00-I99)  66222  67133  65796  62598
# 9                         호흡계통의 질환 (J00-J98,U04)  11112   9871   9586   8419
# 10                            소화계통의 질환 (K00-K92)  20051  18724  18597  17893
# ...
