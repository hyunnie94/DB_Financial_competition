# %%
import seaborn as sns
import numpy as np
import pandas as pd
from pandas import DataFrame as df
from pandas import Series
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy.stats as sp
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
import sys
rc('font', family=font_name)
# %matplotlib inline

# %%
healthdata2014 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\건강검진데이터\건강검진정보_2014.csv", delimiter=',', engine="python")
healthdata2015 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\건강검진데이터\건강검진정보_2015.csv", delimiter=',', engine="python")
healthdata2016 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\건강검진데이터\건강검진정보_2016.csv", delimiter=',', engine="python")
healthdata2017 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\건강검진데이터\건강검진정보_2017.csv", delimiter=',', engine="python")
healthdata2018 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\건강검진데이터\건강검진정보_2018.csv", delimiter=',', engine="python")

# %%
healthdata2014 = healthdata2014.drop(['기준년도','가입자일련번호', '시도코드', '신장(5Cm단위)' ,'체중(5Kg단위)','시력(좌)', '시력(우)',
                                      '청력(좌)', '청력(우)', '구강검진 수검여부', '치아우식증유무',
                                      '치석유무', '데이터 기준일자'], axis=1)

# %%
healthdata2014 = healthdata2014.dropna(axis=0, how='any')

# %%
healthdata2014.isnull().sum()
# Out:
# 성별코드           0
# 연령대코드(5세단위)    0
# BMI            0
# 허리둘레           0
# 수축기혈압          0
# 이완기혈압          0
# 식전혈당(공복혈당)     0
# 총콜레스테롤         0
# 트리글리세라이드       0
# HDL콜레스테롤       0
# LDL콜레스테롤       0
# 혈색소            0
# 요단백            0
# 혈청크레아티닌        0
# (혈청지오티)AST     0
# (혈청지오티)ALT     0
# 감마지티피          0
# 흡연상태           0
# 음주여부           0
# dtype: int64

# %%
healthdata2015 = healthdata2015.drop(['기준년도','가입자일련번호', '시도코드', '신장(5Cm단위)' ,'체중(5Kg단위)', '시력(좌)', '시력(우)',
                                      '청력(좌)', '청력(우)', '구강검진 수검여부', '치아우식증유무',
                                      '치석유무', '데이터 기준일자'], axis=1)

# %%
healthdata2015 = healthdata2015.dropna(axis=0, how='any')

# %%
healthdata2015.isnull().sum()
# Out:
# 성별코드           0
# 연령대코드(5세단위)    0
# BMI            0
# 허리둘레           0
# 수축기혈압          0
# 이완기혈압          0
# 식전혈당(공복혈당)     0
# 총콜레스테롤         0
# 트리글리세라이드       0
# HDL콜레스테롤       0
# LDL콜레스테롤       0
# 혈색소            0
# 요단백            0
# 혈청크레아티닌        0
# (혈청지오티)AST     0
# (혈청지오티)ALT     0
# 감마지티피          0
# 흡연상태           0
# 음주여부           0
# dtype: int64

# %%
healthdata2016 = healthdata2016.drop(['기준년도','가입자일련번호', '시도코드', '신장(5Cm단위)' ,'체중(5Kg단위)', '시력(좌)', '시력(우)',
                                      '청력(좌)', '청력(우)', '구강검진 수검여부', '치아우식증유무', '결손치유무',
                                      '치석', '치아마모증유무', '제3대구치(사랑니)이상','데이터공개일자'], axis=1)

# %%
healthdata2016 = healthdata2016.dropna(axis=0, how='any')

# %%
healthdata2016.isnull().sum()
# Out:
# 성별코드           0
# 연령대코드(5세단위)    0
# BMI            0
# 허리둘레           0
# 수축기혈압          0
# 이완기혈압          0
# 식전혈당(공복혈당)     0
# 총콜레스테롤         0
# 트리글리세라이드       0
# HDL콜레스테롤       0
# LDL콜레스테롤       0
# 혈색소            0
# 요단백            0
# 혈청크레아티닌        0
# (혈청지오티)AST     0
# (혈청지오티)ALT     0
# 감마지티피          0
# 흡연상태           0
# 음주여부           0
# dtype: int64

# %%
healthdata2017 = healthdata2017.drop(['기준년도','가입자일련번호', '시도코드', '신장(5Cm단위)' ,'체중(5Kg단위)', '시력(좌)', '시력(우)',
                                      '청력(좌)', '청력(우)', '구강검진 수검여부', '치아우식증유무', '결손치유무',
                                      '치석', '치아마모증유무', '제3대구치(사랑니)이상','데이터공개일자'], axis=1)

# %%
healthdata2017 = healthdata2017.dropna(axis=0, how='any')

# %%
healthdata2017.isnull().sum()
# Out:
# 성별코드           0
# 연령대코드(5세단위)    0
# BMI            0
# 허리둘레           0
# 수축기혈압          0
# 이완기혈압          0
# 식전혈당(공복혈당)     0
# 총콜레스테롤         0
# 트리글리세라이드       0
# HDL콜레스테롤       0
# LDL콜레스테롤       0
# 혈색소            0
# 요단백            0
# 혈청크레아티닌        0
# (혈청지오티)AST     0
# (혈청지오티)ALT     0
# 감마지티피          0
# 흡연상태           0
# 음주여부           0
# dtype: int64

# %%
healthdata2018 = healthdata2018.drop(['기준년도','가입자일련번호','신장(5Cm단위)' ,'체중(5Kg단위)', '시도코드', '시력(좌)', '시력(우)',
                                      '청력(좌)', '청력(우)', '구강검진수검여부', '치아우식증유무', '결손치유무',
                                      '치석', '치아마모증유무', '제3대구치(사랑니)이상','데이터공개일자'], axis=1)

# %%
healthdata2018 = healthdata2018.dropna(axis=0, how='any')

# %%
healthdata2018.isnull().sum()
# Out:
# 성별코드           0
# 연령대코드(5세단위)    0
# BMI            0
# 허리둘레           0
# 수축기혈압          0
# 이완기혈압          0
# 식전혈당(공복혈당)     0
# 총콜레스테롤         0
# 트리글리세라이드       0
# HDL콜레스테롤       0
# LDL콜레스테롤       0
# 혈색소            0
# 요단백            0
# 혈청크레아티닌        0
# (혈청지오티)AST     0
# (혈청지오티)ALT     0
# 감마지티피          0
# 흡연상태           0
# 음주여부           0
# dtype: int64

# %%
healthdataAll = pd.concat([healthdata2014, healthdata2015, healthdata2016, healthdata2017, healthdata2018])

# %%
healthdataAll
# Out:
#         성별코드  연령대코드(5세단위)   BMI   허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 0          1            6  23.1   79.0  110.0   70.0        84.0   203.0
# 1          2           18  28.9   79.0  135.0   80.0       165.0   168.0
# 2          1           12  24.2   95.0  145.0   91.0       284.0   166.0
# 3          2           11  29.4  104.0  158.0  100.0        87.0   267.0
# 4          1            6  24.5   81.0  110.0   60.0        95.0   188.0
# ...      ...          ...   ...    ...    ...    ...         ...     ...
# 999978     1            8  20.1   77.0  123.0   89.0        92.0   158.0
# 999979     1           13  25.0   87.0  129.0   70.0        82.0   274.0
# 999981     2           14  22.9   83.0  146.0   69.0        99.0   216.0
# 999982     2           14  22.9   84.0  130.0   80.0        95.0   222.0
# 999983     1           13  27.3   88.5  134.0   96.0       105.0   148.0
#
#         트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# ...

# %%
manAlldata = healthdataAll[healthdataAll['성별코드'] == 1]

# %%
manAlldata
# Out:
#         성별코드  연령대코드(5세단위)   BMI  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 0          1            6  23.1  79.0  110.0   70.0        84.0   203.0
# 2          1           12  24.2  95.0  145.0   91.0       284.0   166.0
# 4          1            6  24.5  81.0  110.0   60.0        95.0   188.0
# 6          1           11  18.4  66.0  122.0   84.0       121.0   264.0
# 9          1            7  26.1  90.0  120.0   75.0        88.0   164.0
# ...      ...          ...   ...   ...    ...    ...         ...     ...
# 999974     1           10  22.0  87.0  110.0   70.0        86.0   217.0
# 999976     1           13  23.9  84.0  160.0   90.0       107.0   219.0
# 999978     1            8  20.1  77.0  123.0   89.0        92.0   158.0
# 999979     1           13  25.0  87.0  129.0   70.0        82.0   274.0
# 999983     1           13  27.3  88.5  134.0   96.0       105.0   148.0
#
#         트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# ...

# %%
womanAlldata = healthdataAll[healthdataAll['성별코드'] == 2]

# %%
womanAlldata
# Out:
#         성별코드  연령대코드(5세단위)   BMI   허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 1          2           18  28.9   79.0  135.0   80.0       165.0   168.0
# 3          2           11  29.4  104.0  158.0  100.0        87.0   267.0
# 5          2           11  25.0   88.0  120.0   70.0       128.0   188.0
# 7          2           11  26.2   93.0  122.0   95.0       115.0   278.0
# 8          2           18  17.9   78.0  126.0   71.0        89.0   153.0
# ...      ...          ...   ...    ...    ...    ...         ...     ...
# 999957     2           13  22.9   71.5  133.0   86.0        97.0   243.0
# 999963     2           10  18.7   69.0  110.0   70.0       115.0   157.0
# 999975     2            9  19.0   72.0  112.0   73.0        87.0   273.0
# 999981     2           14  22.9   83.0  146.0   69.0        99.0   216.0
# 999982     2           14  22.9   84.0  130.0   80.0        95.0   222.0
#
#         트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# ...

# %%
#남자는 연령대코드 2까지, 여자는 3까지 삭제

# %%
i1 = manAlldata[manAlldata['연령대코드(5세단위)'] <= 2].index
manAlldata = manAlldata.drop(i1)

# %%
i2 = womanAlldata[womanAlldata['연령대코드(5세단위)'] <= 3].index
womanAlldata = womanAlldata.drop(i2)

# %%
manAlldata
# Out:
#         성별코드  연령대코드(5세단위)   BMI  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 0          1            6  23.1  79.0  110.0   70.0        84.0   203.0
# 2          1           12  24.2  95.0  145.0   91.0       284.0   166.0
# 4          1            6  24.5  81.0  110.0   60.0        95.0   188.0
# 6          1           11  18.4  66.0  122.0   84.0       121.0   264.0
# 9          1            7  26.1  90.0  120.0   75.0        88.0   164.0
# ...      ...          ...   ...   ...    ...    ...         ...     ...
# 999974     1           10  22.0  87.0  110.0   70.0        86.0   217.0
# 999976     1           13  23.9  84.0  160.0   90.0       107.0   219.0
# 999978     1            8  20.1  77.0  123.0   89.0        92.0   158.0
# 999979     1           13  25.0  87.0  129.0   70.0        82.0   274.0
# 999983     1           13  27.3  88.5  134.0   96.0       105.0   148.0
#
#         트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# ...

# %%
womanAlldata
# Out:
#         성별코드  연령대코드(5세단위)   BMI   허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  \
# 1          2           18  28.9   79.0  135.0   80.0       165.0   168.0
# 3          2           11  29.4  104.0  158.0  100.0        87.0   267.0
# 5          2           11  25.0   88.0  120.0   70.0       128.0   188.0
# 7          2           11  26.2   93.0  122.0   95.0       115.0   278.0
# 8          2           18  17.9   78.0  126.0   71.0        89.0   153.0
# ...      ...          ...   ...    ...    ...    ...         ...     ...
# 999957     2           13  22.9   71.5  133.0   86.0        97.0   243.0
# 999963     2           10  18.7   69.0  110.0   70.0       115.0   157.0
# 999975     2            9  19.0   72.0  112.0   73.0        87.0   273.0
# 999981     2           14  22.9   83.0  146.0   69.0        99.0   216.0
# 999982     2           14  22.9   84.0  130.0   80.0        95.0   222.0
#
#         트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  \
# ...

# %%
manAlldata.hist(bins = 40, figsize=(20, 15))
plt.show()

# %%
womanAlldata.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# ### 남자 데이터

# %%
#manAlldata['흡연상태'] = manAlldata['흡연상태'].astype(str)
#manAlldata = display(pd.get_dummies(manAlldata, columns=['흡연상태']))

# %% [markdown]
# ### 데이터 프레임을 직접 처리하는 변환기

# %%
from sklearn.model_selection import StratifiedShuffleSplit #계층적 샘플링

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
#n_splits : 생성할 training set 수
for train_index, test_index in split.split(manAlldata, manAlldata["연령대코드(5세단위)"]):
    #split 함수 str.split(seq, maxsplit) -> seq를 기준으로 분리. maxsplit+1개로 분리.
    strat_train_set = manAlldata.loc[train_index]
    strat_test_set = manAlldata.loc[test_index]
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   import sys
# C:\Users\digus\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
manAlldata["연령대코드(5세단위)"].value_counts() / len(manAlldata)
# Out:
# 9     0.143143
# 11    0.123322
# 10    0.116156
# 8     0.104940
# 12    0.103012
# 7     0.099972
# 13    0.094684
# 6     0.065575
# 14    0.050013
# 15    0.043801
# 16    0.021626
# 5     0.019647
# 17    0.012032
# 18    0.002077
# Name: 연령대코드(5세단위), dtype: float64

# %%
manAlldata = strat_train_set.copy()

# %%
corr_matrix = manAlldata.corr()

# %%
corr_matrix['연령대코드(5세단위)'].sort_values(ascending=False)
# Out:
# 연령대코드(5세단위)    1.000000
# 식전혈당(공복혈당)     0.195101
# 수축기혈압          0.167801
# 허리둘레           0.074951
# 요단백            0.067844
# 음주여부           0.052367
# 이완기혈압          0.042795
# 혈청크레아티닌        0.032991
# (혈청지오티)AST     0.029130
# 감마지티피          0.023203
# 트리글리세라이드      -0.020560
# LDL콜레스테롤      -0.051200
# HDL콜레스테롤      -0.055491
# 총콜레스테롤        -0.072415
# BMI           -0.081960
# (혈청지오티)ALT    -0.086027
# 흡연상태          -0.118047
# 혈색소           -0.313155
# 성별코드                NaN
# Name: 연령대코드(5세단위), dtype: float64

# %%
manAlldata = strat_train_set.drop('연령대코드(5세단위)', axis = 1)   #X_train
manAlldata_labels = strat_train_set['연령대코드(5세단위)'].copy()    #y_train

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.pipeline import FeatureUnion

num_attribs = list(manAlldata)

num_pipeline = Pipeline([
    ('selector', DataFrameSelector(num_attribs)),
    ('std_scaler', StandardScaler()),
])

# %%
manAlldata
# Out:
#          성별코드   BMI  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  트리글리세라이드  \
# 565082    1.0  23.1  86.0  122.0   81.0        84.0   241.0     220.0
# 1067359   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 1398862   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 882964    1.0  24.2  86.0  130.0   70.0       176.0   170.0     114.0
# 882964    1.0  26.1  85.0  126.0   80.0       112.0   101.0      94.0
# ...       ...   ...   ...    ...    ...         ...     ...       ...
# 545464    1.0  26.1  87.0  118.0   78.0       110.0   155.0     308.0
# 545464    1.0  22.5  82.0  108.0   72.0        97.0   221.0     109.0
# 656563    1.0  29.4  96.0  120.0   80.0        89.0   185.0     208.0
# 1772263   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 253436    1.0  26.0  92.0  137.0   71.0       102.0   201.0     227.0
#
#          HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  \
# ...

# %%
manAlldata_prepared = num_pipeline.fit_transform(manAlldata)

# %%
manAlldata_prepared
# Out:
# array([[ 0.        , -0.46548676,  0.16514593, ...,  0.97742572,
#          1.11913891, -0.93596613],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        ...,
#        [ 0.        ,  1.48438941,  1.38229681, ...,  0.07294432,
#          1.11913891,  1.06841473],
#        [        nan,         nan,         nan, ...,         nan,
#                 nan,         nan],
#        [ 0.        ,  0.43207528,  0.89543646, ...,  0.69268158,
#         -0.0847565 , -0.93596613]])

# %%
manAlldata_prepared = manAlldata_prepared[~np.isnan(manAlldata_prepared).any(axis=1)]

# %%
manAlldata_prepared.shape
# Out:
# (1419607, 18)

# %%
manAlldata_labels = manAlldata_labels.dropna()

# %%
manAlldata_test = strat_test_set.drop('연령대코드(5세단위)', axis = 1)    #X_test
manAlldata_test_labels = strat_test_set['연령대코드(5세단위)'].copy()     #y_test

# %%
manAlldata_test_prepared = num_pipeline.fit_transform(manAlldata_test)

# %%
manAlldata_test_prepared = manAlldata_test_prepared[~np.isnan(manAlldata_test_prepared).any(axis=1)]

# %%
manAlldata_test_labels = manAlldata_test_labels.dropna()

# %% [markdown]
# ### 랜덤 포레스트 사용(1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
forest_reg = RandomForestRegressor()
forest_reg.fit(manAlldata_prepared, manAlldata_labels)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
man_predictions = forest_reg.predict(manAlldata_prepared)
forest_mse = mean_squared_error(manAlldata_labels, man_predictions)
forest_rmse = np.sqrt(forest_mse)

# %%
forest_rmse
# Out:
# 0.9341119636529283

# %%
from sklearn.metrics import accuracy_score

# %%
manAlldata_labels.head(20)
# Out:
# 565082     9.0
# 882964    13.0
# 882964    12.0
# 882964    10.0
# 882964    13.0
# 274229    17.0
# 274229    10.0
# 351012    12.0
# 351012     5.0
# 883741    10.0
# 883741     9.0
# 802642     9.0
# 802642    11.0
# 802642    11.0
# 372093    10.0
# 372093    13.0
# 277149    10.0
# 908175     9.0
# 343831     5.0
# 343831    10.0
# Name: 연령대코드(5세단위), dtype: float64

# %%
manAlldata.head(20)
# Out:
#          성별코드   BMI  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  트리글리세라이드  \
# 565082    1.0  23.1  86.0  122.0   81.0        84.0   241.0     220.0
# 1067359   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 1398862   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 882964    1.0  24.2  86.0  130.0   70.0       176.0   170.0     114.0
# 882964    1.0  26.1  85.0  126.0   80.0       112.0   101.0      94.0
# 882964    1.0  26.0  82.0  103.0   66.0        99.0   249.0     180.0
# 882964    1.0  22.5  85.0  122.0   78.0        98.0   141.0      59.0
# 1083810   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 1270461   NaN   NaN   NaN    NaN    NaN         NaN     NaN       NaN
# 274229    1.0  23.9  95.0  117.0   85.0        94.0   175.0     157.0
# 274229    1.0  27.8  93.0  138.0   84.0        84.0   202.0     335.0
# 351012    1.0  25.7  82.4  105.0   73.0        97.0   171.0     306.0
# ...

# %%
manAlldata.iloc[5]
# Out:
# 성별코드            1.0
# BMI            26.0
# 허리둘레           82.0
# 수축기혈압         103.0
# 이완기혈압          66.0
# 식전혈당(공복혈당)     99.0
# 총콜레스테롤        249.0
# 트리글리세라이드      180.0
# HDL콜레스테롤       62.0
# LDL콜레스테롤      151.0
# 혈색소            14.6
# 요단백             1.0
# 혈청크레아티닌         0.7
# (혈청지오티)AST     23.0
# (혈청지오티)ALT     22.0
# 감마지티피          19.0
# 흡연상태            2.0
# 음주여부            1.0
# Name: 882964, dtype: float64

# %%
man_predictions = man_predictions.tolist()

# %%
man_predictions
# Out:
# [9.0,
#  12.1,
#  11.7,
#  10.3,
#  11.7,
#  15.6,
#  9.0,
#  12.0,
#  5.2,
#  10.4,
#  9.0,
#  9.2,
#  9.7,
#  10.9,
#  8.9,
#  11.2,
#  11.6,
#  8.3,
#  5.0,
#  10.2,
#  10.0,
#  12.4,
#  14.6,
#  11.2,
#  8.9,
#  13.1,
#  7.5,
#  14.0,
#  9.7,
#  9.1,
#  11.9,
#  5.7,
#  10.0,
#  10.4,
#  7.7,
#  8.5,
#  9.7,
#  7.8,
#  8.6,
#  12.6,
#  9.6,
#  8.7,
#  8.5,
#  10.4,
#  14.7,
#  8.0,
#  6.9,
#  6.0,
#  9.2,
#  10.7,
#  10.0,
#  5.7,
#  9.1,
#  8.8,
#  14.4,
#  12.9,
#  11.6,
#  11.5,
#  6.6,
#  12.2,
#  15.3,
#  6.8,
#  7.9,
#  7.4,
#  8.1,
#  12.3,
#  7.4,
#  10.3,
#  10.8,
#  8.7,
#  7.9,
#  8.5,
#  9.9,
#  8.8,
#  8.3,
#  9.1,
#  6.7,
#  13.3,
#  13.8,
#  11.0,
#  12.6,
#  7.5,
#  8.7,
#  7.9,
#  9.6,
#  8.5,
#  12.7,
#  13.4,
#  10.0,
#  6.5,
#  9.1,
#  6.6,
#  9.3,
#  7.6,
#  8.8,
#  12.7,
#  8.5,
#  9.3,
#  10.8,
#  9.2,
#  8.9,
#  15.9,
#  7.6,
#  13.8,
#  8.2,
#  12.7,
#  9.1,
#  10.5,
#  15.1,
#  10.3,
#  10.2,
#  9.9,
#  13.9,
#  9.7,
#  9.8,
#  13.3,
#  12.7,
#  11.6,
# ...

# %%
for name, score in zip(manAlldata.columns, forest_reg.feature_importances_):
    print(name, score)
    
# 각 특성 중요도
# Out:
# 성별코드 0.0
# BMI 0.10930289563858106
# 허리둘레 0.06479433274688287
# 수축기혈압 0.06575239634418883
# 이완기혈압 0.04780901694093502
# 식전혈당(공복혈당) 0.09931505460916927
# 총콜레스테롤 0.0553878465150219
# 트리글리세라이드 0.059736180377808215
# HDL콜레스테롤 0.05011864235638308
# LDL콜레스테롤 0.05070988995146456
# 혈색소 0.14198152526905974
# 요단백 0.003980131692125232
# 혈청크레아티닌 0.03180148398275541
# (혈청지오티)AST 0.054638353519951055
# (혈청지오티)ALT 0.06283127229456426
# 감마지티피 0.05328109335412249
# 흡연상태 0.04115593161536683
# 음주여부 0.007403952791620235

# %%
# 모델 교차 검증

# %%
#from sklearn.model_selection import cross_val_score
# scoring 매개변수가 클수록 좋다. (비용함수 아니고 효용함수)
# -> 그래서 음수값을 계산한 다음 제곱근 구할땐 부호를 바꿔준다.

#scores = cross_val_score(forest_reg, manAlldata_prepared, manAlldata_labels,
#                        scoring="neg_mean_squared_error", cv=10)
#tree_rmse_scores = np.sqrt(-scores)

# %%
#def display_scores(scores):
#    print("Scores:", scores)
#    print("Mean:", scores.mean())
#    print("Standard deviation:", scores.std())

# %%
#display_scores(tree_rmse_scores)

# %% [markdown]
# ### 그래디언트부스팅

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbrt = GradientBoostingRegressor(max_depth=4, n_estimators=120, learning_rate=0.1)
gbrt.fit(manAlldata_prepared, manAlldata_labels)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=4,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=120,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gbrt_predictions = gbrt.predict(manAlldata_prepared)
gbrt_mse = mean_squared_error(manAlldata_labels, gbrt_predictions)
gbrt_rmse = np.sqrt(gbrt_mse)

# %%
gbrt_rmse
# Out:
# 2.0724316240027907

# %% [markdown]
# ### 선형회귀

# %%
from sklearn.linear_model import LinearRegression

lin_reg = LinearRegression()
lin_reg.fit(manAlldata_prepared, manAlldata_labels)
#완전히 작동하는 선형 회귀 모델
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("예측: ", lin_reg.predict(manAlldata_prepared))
# Out:
# 예측:  [ 8.92551835 10.90800023  9.99669676 ...  9.63955182 10.08827057
#  11.57065997]

# %%
lin_man_predictions = lin_reg.predict(manAlldata_prepared)
lin_mse = mean_squared_error(manAlldata_labels, lin_man_predictions)
lin_rmse = np.sqrt(lin_mse)

# %%
lin_rmse
# Out:
# 2.4313537153127744

# %% [markdown]
# ### 다항회귀

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
poly_features = PolynomialFeatures(degree=2, include_bias = False)

# %%
man_poly = poly_features.fit_transform(manAlldata_prepared) #원래 특성(manAlldata_prepared)과 특성 제곱 포함

# %%
poly_reg = LinearRegression()
poly_reg.fit(man_poly, manAlldata_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
poly_man_predictions = poly_reg.predict(man_poly)
poly_mse = mean_squared_error(manAlldata_labels, poly_man_predictions)
poly_rmse = np.sqrt(poly_mse)

# %%
poly_rmse
# Out:
# 2.2995827447552215

# %%
# 회귀분석은 원래 정확한 값을 반환하지 못함. 가장 비슷한 값을 예측해줄뿐.

# %% [markdown]
# ### 여자 데이터

# %%
from sklearn.model_selection import StratifiedShuffleSplit #계층적 샘플링

split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
#n_splits : 생성할 training set 수
for train_index, test_index in split.split(womanAlldata, womanAlldata["연령대코드(5세단위)"]):
    #split 함수 str.split(seq, maxsplit) -> seq를 기준으로 분리. maxsplit+1개로 분리.
    strat_train_set_2 = womanAlldata.loc[train_index]
    strat_test_set_2 = womanAlldata.loc[test_index]
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   import sys
# C:\Users\digus\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike

# %%
womanAlldata["연령대코드(5세단위)"].value_counts() / len(womanAlldata)
# Out:
# 9     0.142651
# 11    0.141231
# 13    0.117899
# 10    0.116893
# 12    0.114277
# 7     0.060321
# 14    0.058809
# 15    0.057758
# 6     0.057208
# 8     0.052793
# 16    0.030470
# 5     0.025878
# 17    0.019239
# 18    0.004574
# Name: 연령대코드(5세단위), dtype: float64

# %%
womanAlldata = strat_train_set_2.copy()

# %%
corr_matrix_2 = womanAlldata.corr()

# %%
corr_matrix_2['연령대코드(5세단위)'].sort_values(ascending=False)
# Out:
# 연령대코드(5세단위)    1.000000
# 수축기혈압          0.398863
# 허리둘레           0.304947
# 트리글리세라이드       0.252022
# BMI            0.247111
# 식전혈당(공복혈당)     0.238619
# 이완기혈압          0.233805
# (혈청지오티)AST     0.155103
# LDL콜레스테롤       0.144404
# 총콜레스테롤         0.138974
# (혈청지오티)ALT     0.127611
# 감마지티피          0.094868
# 혈청크레아티닌        0.041975
# 음주여부           0.034744
# 요단백            0.016485
# 혈색소           -0.002671
# 흡연상태          -0.096816
# HDL콜레스테롤      -0.212577
# 성별코드                NaN
# Name: 연령대코드(5세단위), dtype: float64

# %%
womanAlldata = strat_train_set_2.drop('연령대코드(5세단위)', axis = 1)
womanAlldata_labels = strat_train_set_2['연령대코드(5세단위)'].copy()

# %%
from sklearn.base import BaseEstimator, TransformerMixin

class DataFrameSelector(BaseEstimator, TransformerMixin):
    def __init__(self, attribute_names):
        self.attribute_names = attribute_names
    def fit(self, X, y=None):
        return self
    def transform(self, X):
        return X[self.attribute_names].values

# %%
womanAlldata = womanAlldata.dropna(axis=0)

# %%
womanAlldata_labels = womanAlldata_labels.dropna(axis=0)

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.pipeline import FeatureUnion

num_attribs_2 = list(womanAlldata)

num_pipeline_2 = Pipeline([
    ('selector', DataFrameSelector(num_attribs_2)),
    ('std_scaler', StandardScaler()),
])

# %%
womanAlldata_prepared = num_pipeline_2.fit_transform(womanAlldata)

# %%
womanAlldata_prepared
# Out:
# array([[ 0.        , -0.12839128, -0.34197867, ..., -0.57386602,
#         -0.23056317,  0.88546049],
#        [ 0.        , -1.09608888, -0.70187805, ..., -0.46689467,
#         -0.23056317,  0.88546049],
#        [ 0.        , -0.38454653,  0.55776976, ..., -0.11032349,
#         -0.23056317,  0.88546049],
#        ...,
#        [ 0.        , -1.94993971, -0.97180258, ...,  0.0679621 ,
#         -0.23056317, -1.12935587],
#        [ 0.        , -0.89685702, -0.6119032 , ...,  0.60281886,
#         -0.23056317,  0.88546049],
#        [ 0.        ,  1.12392327,  0.91766913, ...,  0.38887616,
#         -0.23056317,  0.88546049]])

# %%
womanAlldata_prepared = womanAlldata_prepared[~np.isnan(womanAlldata_prepared).any(axis=1)]

# %%
womanAlldata_prepared.shape
# Out:
# (1218355, 18)

# %%
womanAlldata_labels = womanAlldata_labels.dropna()

# %%
womanAlldata_test = strat_test_set_2.drop('연령대코드(5세단위)', axis = 1)    #X_test
womanAlldata_test_labels = strat_test_set_2['연령대코드(5세단위)'].copy()     #y_test

# %%
womanAlldata_test_prepared = num_pipeline_2.fit_transform(womanAlldata_test)

# %%
womanAlldata_test_prepared = womanAlldata_test_prepared[~np.isnan(womanAlldata_test_prepared).any(axis=1)]

# %%
womanAlldata_test_labels = womanAlldata_test_labels.dropna()

# %% [markdown]
# ### 랜덤포레스트 사용(1)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
forest_reg_2 = RandomForestRegressor()
forest_reg_2.fit(womanAlldata_prepared, womanAlldata_labels)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10,
#                       n_jobs=None, oob_score=False, random_state=None,
#                       verbose=0, warm_start=False)

# %%
woman_predictions = forest_reg_2.predict(womanAlldata_prepared)
forest_mse_2 = mean_squared_error(womanAlldata_labels, woman_predictions)
forest_rmse_2 = np.sqrt(forest_mse_2)

# %%
forest_rmse_2
# Out:
# 0.9065872780100641

# %%
womanAlldata_labels.head(10)
# Out:
# 523854    12.0
# 523854    11.0
# 523854    14.0
# 784423    11.0
# 784423     7.0
# 784423     9.0
# 566717     8.0
# 566717     9.0
# 701196    11.0
# 178541     6.0
# Name: 연령대코드(5세단위), dtype: float64

# %%
womanAlldata
# Out:
#         성별코드   BMI  허리둘레  수축기혈압  이완기혈압  식전혈당(공복혈당)  총콜레스테롤  트리글리세라이드  \
# 523854   2.0  22.9  73.0  115.0   70.0       117.0   171.0      63.0
# 523854   2.0  19.5  69.0  130.0   80.0       100.0   196.0      31.0
# 523854   2.0  22.0  83.0  134.0   72.0        98.0   211.0      91.0
# 784423   2.0  27.3  91.0  120.0   80.0       105.0   178.0      96.0
# 784423   2.0  21.5  71.0  119.0   73.0        86.0   156.0      53.0
# ...      ...   ...   ...    ...    ...         ...     ...       ...
# 253068   2.0  23.9  76.1  104.0   62.0       101.0   152.0      63.0
# 503914   2.0  18.4  63.0  111.0   66.0        80.0   165.0      53.0
# 503914   2.0  16.5  66.0  100.0   70.0        81.0   124.0     120.0
# 287854   2.0  20.2  70.0  110.0   70.0       108.0   175.0      59.0
# 287854   2.0  27.3  87.0  133.0   81.0       119.0   235.0     111.0
#
#         HDL콜레스테롤  LDL콜레스테롤   혈색소  요단백  혈청크레아티닌  (혈청지오티)AST  (혈청지오티)ALT  감마지티피  \
# ...

# %%
woman_predictions = woman_predictions.tolist()

# %%
woman_predictions
# Out:
# [12.0,
#  10.7,
#  14.2,
#  10.9,
#  7.7,
#  9.7,
#  8.7,
#  8.6,
#  11.2,
#  6.7,
#  10.1,
#  13.0,
#  12.7,
#  13.0,
#  12.0,
#  12.8,
#  12.7,
#  14.7,
#  13.1,
#  8.1,
#  11.7,
#  9.0,
#  10.0,
#  11.2,
#  11.1,
#  6.7,
#  11.5,
#  11.9,
#  14.1,
#  14.2,
#  11.2,
#  12.8,
#  13.4,
#  11.8,
#  12.0,
#  10.1,
#  10.5,
#  11.4,
#  15.6,
#  12.2,
#  10.6,
#  8.9,
#  6.6,
#  9.3,
#  13.6,
#  11.9,
#  12.3,
#  7.6,
#  9.8,
#  11.2,
#  11.0,
#  14.9,
#  12.8,
#  11.4,
#  9.5,
#  10.8,
#  9.9,
#  11.4,
#  11.1,
#  9.9,
#  10.0,
#  9.2,
#  7.3,
#  10.6,
#  12.2,
#  11.4,
#  11.9,
#  6.7,
#  13.3,
#  11.7,
#  10.9,
#  9.6,
#  10.8,
#  8.8,
#  10.5,
#  12.8,
#  13.5,
#  6.4,
#  11.7,
#  15.3,
#  13.7,
#  8.0,
#  8.1,
#  14.9,
#  10.6,
#  10.7,
#  7.9,
#  11.3,
#  11.4,
#  11.2,
#  6.6,
#  9.9,
#  12.6,
#  11.6,
#  11.9,
#  11.8,
#  11.1,
#  10.2,
#  13.5,
#  12.8,
#  13.1,
#  12.7,
#  9.0,
#  11.0,
#  13.1,
#  8.6,
#  8.5,
#  10.7,
#  10.8,
#  6.5,
#  9.5,
#  6.9,
#  10.7,
#  14.4,
# ...

# %%
for name, score in zip(womanAlldata.columns, forest_reg_2.feature_importances_):
    print(name, score)
    
# 각 특성 중요도
# Out:
# 성별코드 0.0
# BMI 0.07920338108331867
# 허리둘레 0.1591478578892926
# 수축기혈압 0.12782126889370643
# 이완기혈압 0.0456744906380294
# 식전혈당(공복혈당) 0.0638502601344397
# 총콜레스테롤 0.04340889815787169
# 트리글리세라이드 0.06951973982318624
# HDL콜레스테롤 0.04858773973306012
# LDL콜레스테롤 0.06044892007305266
# 혈색소 0.05321276261262968
# 요단백 0.003990437525974998
# 혈청크레아티닌 0.031312917285435025
# (혈청지오티)AST 0.1101433242583151
# (혈청지오티)ALT 0.04735605279753724
# 감마지티피 0.04111768076801544
# 흡연상태 0.007731582595259777
# 음주여부 0.007472685730875337

# %% [markdown]
# ### 선형회귀

# %%
from sklearn.linear_model import LinearRegression

lin_reg_2 = LinearRegression()
lin_reg_2.fit(womanAlldata_prepared, womanAlldata_labels)
#완전히 작동하는 선형 회귀 모델
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
print("예측: ", lin_reg_2.predict(womanAlldata_prepared))
# Out:
# 예측:  [10.06762571 10.97474551 12.58408942 ...  8.47079696  9.34281658
#  12.79129103]

# %%
lin_woman_predictions = lin_reg.predict(womanAlldata_prepared)
lin_mse_2 = mean_squared_error(womanAlldata_labels, lin_woman_predictions)
lin_rmse_2 = np.sqrt(lin_mse_2)

# %%
lin_rmse_2
# Out:
# 2.8194991345369447

# %% [markdown]
# ### 다항회귀

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
poly_features_2 = PolynomialFeatures(degree=2, include_bias = False)

# %%
woman_poly = poly_features_2.fit_transform(womanAlldata_prepared) #원래 특성(manAlldata_prepared)과 특성 제곱 포함

# %%
poly_reg_2 = LinearRegression()
poly_reg_2.fit(woman_poly, womanAlldata_labels)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
poly_woman_predictions = poly_reg_2.predict(woman_poly)
poly_mse_2 = mean_squared_error(womanAlldata_labels, poly_woman_predictions)
poly_rmse_2 = np.sqrt(poly_mse_2)

# %%
poly_rmse_2
# Out:
# 2.2500690345891305

# %% [markdown]
# ### 그래디언트 부스팅

# %%
from sklearn.ensemble import GradientBoostingRegressor

gbrt_2 = GradientBoostingRegressor(max_depth=4, n_estimators=120, learning_rate=0.1)
gbrt_2.fit(womanAlldata_prepared, womanAlldata_labels)
# Out:
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#                           learning_rate=0.1, loss='ls', max_depth=4,
#                           max_features=None, max_leaf_nodes=None,
#                           min_impurity_decrease=0.0, min_impurity_split=None,
#                           min_samples_leaf=1, min_samples_split=2,
#                           min_weight_fraction_leaf=0.0, n_estimators=120,
#                           n_iter_no_change=None, presort='auto',
#                           random_state=None, subsample=1.0, tol=0.0001,
#                           validation_fraction=0.1, verbose=0, warm_start=False)

# %%
gbrt_woman_predictions = gbrt_2.predict(womanAlldata_prepared)
gbrt_mse_2 = mean_squared_error(womanAlldata_labels, gbrt_woman_predictions)
gbrt_rmse_2 = np.sqrt(gbrt_mse_2)

# %%
gbrt_rmse_2
# Out:
# 1.9929113606370892
