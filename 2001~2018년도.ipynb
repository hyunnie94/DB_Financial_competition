# %%
import seaborn as sns
import numpy as np
import pandas as pd
from pandas import DataFrame as df
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy.stats as sp
import matplotlib
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

# %%
#data2001 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2001.csv", engine='python')
#data2002 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2002.csv", engine="python")
#data2003 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2003.csv", engine="python")
data2004 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2004.csv", engine="python")
data2005 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2005.csv", engine="python")
data2006 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2006.csv", engine="python")
data2007 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2007.csv", engine='python')
data2008 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2008.csv", engine="python")
data2009 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2009.csv", engine="python")
data2010 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2010.csv", engine="python")
data2011 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2011.csv", engine="python")
data2012 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2012.csv", engine="python")
data2013 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2013.csv", engine='python')
data2014 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2014.csv", engine="python")
data2015 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2015.csv", engine="python")
data2016 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2016.csv", engine="python")
data2017 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2017.csv", engine="python")
data2018 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2018.csv", engine="python")

# %%
#95,96,97,98,99,100, 101, 102, 103  -사고사

# %%
#a1 = data2001[(data2001['103항목'] >= 95 )].index
#data2001 = data2001.drop(a1)

# %%
#a2 = data2002[(data2002['103항목'] >= 95 )].index
#data2002 = data2002.drop(a2)

# %%
#a3 = data2003[(data2003['103항목'] >= 95 )].index
#data2003 = data2003.drop(a3)

# %%
a4 = data2004[(data2004['103항목'] >= 95 )].index
data2004 = data2004.drop(a4)

# %%
data2004
# Out:
#         성별  사망나이  사망코드  103항목
# 0       남성     0  A052      4
# 1       남성     0  A052      4
# 2       남성     0  A052      4
# 3       남성     0  A099      3
# 4       남성     0  A099      3
# ...     ..   ...   ...    ...
# 246204  여성   112   R54     94
# 246205  여성   113   R53     94
# 246206  여성   113   R54     94
# 246208  여성   114   R54     94
# 246209  여성   114   R54     94
#
# [215488 rows x 4 columns]

# %%
a5 = data2005[(data2005['103항목'] >= 95 )].index
data2005 = data2005.drop(a5)

# %%
a6 = data2006[(data2006['103항목'] >= 95 )].index
data2006 = data2006.drop(a6)

# %%
a7 = data2007[(data2007['103항목'] >= 95 )].index
data2007 = data2007.drop(a7)

# %%
a8 = data2008[(data2008['103항목'] >= 95 )].index
data2008 = data2008.drop(a8)

# %%
a9 = data2009[(data2009['103항목'] >= 95 )].index
data2009 = data2009.drop(a9)

# %%
a10 = data2010[(data2010['103항목'] >= 95 )].index
data2010 = data2010.drop(a10)

# %%
a11 = data2011[(data2011['103항목'] >= 95 )].index
data2011 = data2011.drop(a11)

# %%
a12 = data2012[(data2012['103항목'] >= 95 )].index
data2012 = data2012.drop(a12)

# %%
a13 = data2013[(data2013['103항목'] >= 95 )].index
data2013 = data2013.drop(a13)

# %%
a14 = data2014[(data2014['103항목'] >= 95 )].index
data2014 = data2014.drop(a14)

# %%
a15 = data2015[(data2015['103항목'] >= 95 )].index
data2015 = data2015.drop(a15)

# %%
a16 = data2016[(data2016['103항목'] >= 95 )].index
data2016 = data2016.drop(a16)

# %%
a17 = data2017[(data2017['103항목'] >= 95 )].index
data2017 = data2017.drop(a17)

# %%
a18 = data2018[(data2018['103항목'] >= 95 )].index
data2018 = data2018.drop(a18)

# %%
Alldata = pd.concat([data2004, data2005, data2006,
                     data2007, data2008, data2009, data2010, data2011, data2012,
                     data2013, data2014, data2015, data2016, data2017, data2018])

# %%
manAlldata = Alldata[Alldata['성별'] == '남성']

# %%
womanAlldata = Alldata[Alldata['성별'] == '여성']

# %%
#b1 = manAlldata[(manAlldata['사망나이'] < 32)].index
#manAlldata = manAlldata.drop(b1)

# %%
#b2 = womanAlldata[(womanAlldata['사망나이'] < 34)].index
#womanAlldata = womanAlldata.drop(b2)

# %%
manAlldata
# Out:
#         성별  사망나이  사망코드  103항목
# 0       남성     0  A052      4
# 1       남성     0  A052      4
# 2       남성     0  A052      4
# 3       남성     0  A099      3
# 4       남성     0  A099      3
# ...     ..   ...   ...    ...
# 161157  남성   108  I709     70
# 161158  남성   108  J189     74
# 161159  남성   108  J189     74
# 161160  남성   108   R54     94
# 161161  남성   108  R688     94
#
# [1853111 rows x 4 columns]

# %%
womanAlldata
# Out:
#         성별  사망나이  사망코드  103항목
# 136233  여성     0  A080      4
# 136234  여성     0  A099      3
# 136235  여성     0  A419     12
# 136236  여성     0  A419     12
# 136237  여성     0  C649     46
# ...     ..   ...   ...    ...
# 298772  여성   110  K810     81
# 298773  여성   110   N10     85
# 298774  여성   110   R54     94
# 298775  여성   111  I258     67
# 298776  여성   111  J189     74
#
# [1623494 rows x 4 columns]

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2004~2018 남자 전체", fontsize=20)

sns.boxplot(manAlldata["사망나이"], ax=ax_box, color = 'dodgerblue')
m = sns.distplot(manAlldata["사망나이"], ax=ax_hist, fit = sp.norm, color = 'dodgerblue')
m.axvline(np.percentile(manAlldata['사망나이'], 2), ymax=1, c = 'b', ls = '--')
m.text(23, 0.030, '하위 2% = 34.0', color = 'blue', size = 20)
# Out:
# Text(23, 0.03, '하위 2% = 34.0')

# %%
np.percentile(manAlldata['사망나이'], 2)
# Out:
# 34.0

# %%
manAlldata["사망나이"].size
# Out:
# 1853111

# %%
manAlldata["사망나이"].describe()
# Out:
# count    1.853111e+06
# mean     6.927905e+01
# std      1.521378e+01
# min      0.000000e+00
# 25%      6.100000e+01
# 50%      7.200000e+01
# 75%      8.000000e+01
# max      1.130000e+02
# Name: 사망나이, dtype: float64

# %%
x1 = np.random.normal(loc = 69.27905, scale= 15.21378, size = 1853111)

# %%
sp.normaltest(x1)
# Out:
# NormaltestResult(statistic=9.827641020399476, pvalue=0.007344375401563489)

# %%
# p- value가 0.05 이상 이므로 귀무가설을 기각 할 수 없다 -> x 가 정규분포를 따른다고 할 수 있다.

# %%
sp.describe(x1)
# Out:
# DescribeResult(nobs=1853111, minmax=(-14.071543800943303, 138.332762630562), mean=69.26817988761626, variance=231.82432488520735, skewness=-0.002727215370984446, kurtosis=-0.009836662691946607)

# %%
sp.skew(x1)  #왜도값이 0에 충분히 가깝기때문에 정규분포에 부합한다
# Out:
# -0.002727215370984446

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2004~2018 여자 전체", fontsize=20)

sns.boxplot(womanAlldata["사망나이"], ax=ax_box, color = 'r')
w = sns.distplot(womanAlldata["사망나이"], ax=ax_hist, fit = sp.norm, color = 'r')
w.axvline(np.percentile(womanAlldata['사망나이'], 2), ymax=1, c = 'r', ls = '--')
w.text(25, 0.030, '하위 2% = 36.0', color = 'darkred', size = 20)
# Out:
# Text(25, 0.03, '하위 2% = 36.0')

# %%
np.percentile(womanAlldata['사망나이'], 2)
# Out:
# 36.0

# %%
womanAlldata["사망나이"].size
# Out:
# 1623494

# %%
womanAlldata["사망나이"].describe()
# Out:
# count    1.623494e+06
# mean     7.704303e+01
# std      1.511087e+01
# min      0.000000e+00
# 25%      7.200000e+01
# 50%      8.000000e+01
# 75%      8.700000e+01
# max      1.140000e+02
# Name: 사망나이, dtype: float64

# %%
x2 = np.random.normal(loc = 77.04303, scale= 15.11087, size = 1623494)

# %%
sp.normaltest(x2)
# Out:
# NormaltestResult(statistic=2.2992329980794732, pvalue=0.3167582231714991)

# %%
sp.describe(x2)
# Out:
# DescribeResult(nobs=1623494, minmax=(1.0940851957481073, 150.97431352150565), mean=77.04198014587058, variance=228.29825943150703, skewness=0.002843094972778581, kurtosis=0.0012767618242426337)

# %%
sp.skew(x2)
# Out:
# 0.002843094972778581

# %% [markdown]
# ## 5개년---------------------

# %%
data0408 = pd.concat([data2004, data2005, data2006, data2007, data2008])

# %%
mandata0408 = data0408[data0408['성별'] == '남성']

# %%
womandata0408 = data0408[data0408['성별'] == '여성']

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2004~2008 남성의 사망 연령", fontsize=20)

sns.boxplot(mandata0408["사망나이"], ax=ax_box, color = 'dodgerblue')
m1 = sns.distplot(mandata0408["사망나이"], ax=ax_hist, fit = sp.norm, color = 'dodgerblue')
m1.axvline(np.percentile(mandata0408['사망나이'], 25), ymax=1, c = 'c', ls = '--')
m1.axvline(np.percentile(mandata0408['사망나이'], 50), ymax=1, c = 'b', ls = '--')
m1.axvline(np.percentile(mandata0408['사망나이'], 75), ymax=1, c = 'c', ls = '--')
m1.text(63, 0.035, '평균 66.98', color = 'blue', size = 20)
# Out:
# Text(63, 0.035, '평균 66.98')

# %%
np.percentile(mandata0408['사망나이'], 2)
# Out:
# 28.0

# %%
mandata0408['사망나이'].describe()
# Out:
# count    575717.000000
# mean         66.988140
# std          15.791164
# min           0.000000
# 25%          58.000000
# 50%          69.000000
# 75%          78.000000
# max         113.000000
# Name: 사망나이, dtype: float64

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2004~2008 여성의 사망 연령", fontsize=20)

sns.boxplot(womandata0408["사망나이"], ax=ax_box, color = 'r')
w1 = sns.distplot(womandata0408["사망나이"], ax=ax_hist, fit = sp.norm, color = 'r')
w1.axvline(np.percentile(womandata0408['사망나이'], 25), ymax=1, c = 'salmon', ls = '--')
w1.axvline(np.percentile(womandata0408['사망나이'], 50), ymax=1, c = 'darkred', ls = '--')
w1.axvline(np.percentile(womandata0408['사망나이'], 75), ymax=1, c = 'salmon', ls = '--')
w1.text(72, 0.04, '평균 74.95', color = 'darkred', size = 20)
# Out:
# Text(72, 0.04, '평균 74.95')

# %%
womandata0408['사망나이'].describe()
# Out:
# count    500721.000000
# mean         74.957004
# std          15.872671
# min           0.000000
# 25%          69.000000
# 50%          78.000000
# 75%          85.000000
# max         114.000000
# Name: 사망나이, dtype: float64

# %%
data0913 = pd.concat([data2009, data2010, data2011, data2012, data2013])

# %%
mandata0913 = data0913[data0913['성별'] == '남성']

# %%
womandata0913 = data0913[data0913['성별'] == '여성']

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2009~2013 남성의 사망 연령", fontsize=20)

sns.boxplot(mandata0913["사망나이"], ax=ax_box, color = 'dodgerblue')
m2 = sns.distplot(mandata0913["사망나이"], ax=ax_hist, fit = sp.norm, color = 'dodgerblue')
m2.axvline(np.percentile(mandata0913['사망나이'], 25), ymax=1, c = 'c', ls = '--')
m2.axvline(np.percentile(mandata0913['사망나이'], 50), ymax=1, c = 'b', ls = '--')
m2.axvline(np.percentile(mandata0913['사망나이'], 75), ymax=1, c = 'c', ls = '--')
m2.text(63, 0.035, '평균 69.08', color = 'blue', size = 20)
# Out:
# Text(63, 0.035, '평균 69.08')

# %%
mandata0913['사망나이'].describe()
# Out:
# count    608701.000000
# mean         69.084344
# std          15.155067
# min           0.000000
# 25%          60.000000
# 50%          72.000000
# 75%          80.000000
# max         111.000000
# Name: 사망나이, dtype: float64

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2009~2013 여성의 사망 연령", fontsize=20)

sns.boxplot(womandata0913["사망나이"], ax=ax_box, color = 'r')
w2 = sns.distplot(womandata0913["사망나이"], ax=ax_hist, fit = sp.norm, color = 'r')
w2.axvline(np.percentile(womandata0913['사망나이'], 25), ymax=1, c = 'salmon', ls = '--')
w2.axvline(np.percentile(womandata0913['사망나이'], 50), ymax=1, c = 'darkred', ls = '--')
w2.axvline(np.percentile(womandata0913['사망나이'], 75), ymax=1, c = 'salmon', ls = '--')
w2.text(72, 0.045, '평균 76.82', color = 'darkred', size = 20)
# Out:
# Text(72, 0.045, '평균 76.82')

# %%
womandata0913['사망나이'].describe()
# Out:
# count    524427.000000
# mean         76.826626
# std          15.076181
# min           0.000000
# 25%          71.000000
# 50%          80.000000
# 75%          87.000000
# max         111.000000
# Name: 사망나이, dtype: float64

# %%
data1418 = pd.concat([data2014, data2015, data2016, data2017, data2018])

# %%
mandata1418 = data1418[data1418['성별'] == '남성']

# %%
womandata1418 = data1418[data1418['성별'] == '여성']

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2014~2018 남성의 사망 연령", fontsize=20)

sns.boxplot(mandata1418["사망나이"], ax=ax_box, color = 'dodgerblue')
m3 = sns.distplot(mandata1418["사망나이"], ax=ax_hist, fit = sp.norm, color = 'dodgerblue')
m3.axvline(np.percentile(mandata1418['사망나이'], 25), ymax=1, c = 'c', ls = '--')
m3.axvline(np.percentile(mandata1418['사망나이'], 50), ymax=1, c = 'b', ls = '--')
m3.axvline(np.percentile(mandata1418['사망나이'], 75), ymax=1, c = 'c', ls = '--')
m3.text(69, 0.04, '평균 71.42', color = 'blue', size = 20)
# Out:
# Text(69, 0.04, '평균 71.42')

# %%
mandata1418['사망나이'].describe()
# Out:
# count    668693.000000
# mean         71.428665
# std          14.439410
# min           0.000000
# 25%          63.000000
# 50%          74.000000
# 75%          82.000000
# max         110.000000
# Name: 사망나이, dtype: float64

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})
f.suptitle("2014~2018 여성의 사망 연령", fontsize=20)

sns.boxplot(womandata1418["사망나이"], ax=ax_box, color = 'r')
w3 = sns.distplot(womandata1418["사망나이"], ax=ax_hist, fit = sp.norm, color = 'r')
w3.axvline(np.percentile(womandata1418['사망나이'], 25), ymax=1, c = 'salmon', ls = '--')
w3.axvline(np.percentile(womandata1418['사망나이'], 50), ymax=1, c = 'darkred', ls = '--')
w3.axvline(np.percentile(womandata1418['사망나이'], 75), ymax=1, c = 'salmon', ls = '--')
w3.text(77, 0.045, '평균 78.97', color = 'darkred', size = 20)
# Out:
# Text(77, 0.045, '평균 78.97')

# %%
womandata1418['사망나이'].describe()
# Out:
# count    598346.000000
# mean         78.978364
# std          14.215356
# min           0.000000
# 25%          74.000000
# 50%          82.000000
# 75%          88.000000
# max         111.000000
# Name: 사망나이, dtype: float64

# %%
mandata2001 = data2001[data2001['성별'] == '남성']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-184cc7fa6b6c> in <module>
# ----> 1 mandata2001 = data2001[data2001['성별'] == '남성']
#
# NameError: name 'data2001' is not defined

# %%
mandata2001.describe()

# %%
mandata2001['사망나이'].mean()

# %%
womandata2001 = data2001[data2001['성별'] == '여성']

# %%
womandata2001.describe()

# %%
mandata2002 = data2002[data2002['성별'] == '남성']
womandata2002 = data2002[data2002['성별'] == '여성']

# %%
mandata2002.describe()

# %%
womandata2002.describe()

# %%
mandata2003 = data2003[data2003['성별'] == '남성']
womandata2003 = data2003[data2003['성별'] == '여성']

# %%
mandata2003.describe()

# %%
womandata2003.describe()

# %%
mandata2004 = data2004[data2004['성별'] == '남성']
womandata2004 = data2004[data2004['성별'] == '여성']

# %%
mandata2004.describe()

# %%
womandata2004.describe()

# %%
mandata2005 = data2005[data2005['성별'] == '남성']
womandata2005 = data2005[data2005['성별'] == '여성']

# %%
mandata2005.describe()

# %%
womandata2005.describe()

# %%
mandata2006 = data2006[data2006['성별'] == '남성']
womandata2006 = data2006[data2006['성별'] == '여성']

# %%
mandata2006.describe()

# %%
womandata2006.describe()

# %%
mandata2007 = data2007[data2007['성별'] == '남성']
womandata2007 = data2007[data2007['성별'] == '여성']

# %%
mandata2007.describe()

# %%
womandata2007.describe()

# %%
mandata2008 = data2008[data2008['성별'] == '남성']
womandata2008 = data2008[data2008['성별'] == '여성']

# %%
mandata2008.describe()

# %%
womandata2008.describe()

# %%
mandata2009 = data2009[data2009['성별'] == '남성']
womandata2009 = data2009[data2009['성별'] == '여성']

# %%
mandata2009.describe()

# %%
womandata2009.describe()

# %%
mandata2010 = data2010[data2010['성별'] == '남성']
womandata2010 = data2010[data2010['성별'] == '여성']

# %%
mandata2010.describe()

# %%
womandata2010.describe()

# %%
mandata2011 = data2011[data2011['성별'] == '남성']
womandata2011 = data2011[data2011['성별'] == '여성']

# %%
mandata2011.describe()

# %%
womandata2011.describe()

# %%
mandata2012 = data2012[data2012['성별'] == '남성']
womandata2012 = data2012[data2012['성별'] == '여성']

# %%
mandata2012.describe()

# %%
womandata2012.describe()

# %%
mandata2013 = data2013[data2013['성별'] == '남성']
womandata2013 = data2013[data2013['성별'] == '여성']

# %%
mandata2013.describe()

# %%
womandata2013.describe()

# %%
mandata2014 = data2014[data2014['성별'] == '남성']
womandata2014 = data2014[data2014['성별'] == '여성']

# %%
mandata2014.describe()

# %%
womandata2014.describe()

# %%
mandata2015 = data2015[data2015['성별'] == '남성']
womandata2015 = data2015[data2015['성별'] == '여성']

# %%
mandata2015.describe()

# %%
womandata2015.describe()

# %%
mandata2016 = data2016[data2016['성별'] == '남성']
womandata2016 = data2016[data2016['성별'] == '여성']

# %%
mandata2016.describe()

# %%
womandata2016.describe()

# %%
mandata2017 = data2017[data2017['성별'] == '남성']
womandata2017 = data2017[data2017['성별'] == '여성']

# %%
mandata2017.describe()

# %%
womandata2017.describe()

# %%
mandata2018 = data2018[data2018['성별'] == '남성']
womandata2018 = data2018[data2018['성별'] == '여성']

# %%
mandata2018.describe()

# %%
womandata2018.describe()

# %%
print(mandata2001['사망나이'].mean())
print(mandata2002['사망나이'].mean())
print(mandata2003['사망나이'].mean())
print(mandata2004['사망나이'].mean())
print(mandata2005['사망나이'].mean())
print(mandata2006['사망나이'].mean())
print(mandata2007['사망나이'].mean())
print(mandata2008['사망나이'].mean())
print(mandata2009['사망나이'].mean())
print(mandata2010['사망나이'].mean())
print(mandata2011['사망나이'].mean())
print(mandata2012['사망나이'].mean())
print(mandata2013['사망나이'].mean())
print(mandata2014['사망나이'].mean())
print(mandata2015['사망나이'].mean())
print(mandata2016['사망나이'].mean())
print(mandata2017['사망나이'].mean())
print(mandata2018['사망나이'].mean())

# %%
mansMean = df(data = {'년도' : [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
                      '사망나이 평균' : [64.48696528127552, 65.06413954008937, 65.33700631531003, 65.93936970223865, 66.61316342616921, 67.02475744688283,
                                          67.43381079395871, 67.91318041002668, 68.11301112674475, 68.55712645208534, 69.0679030711759,
                                          69.64775265767835, 69.93527995663541, 70.34233243525595, 70.91509022952924, 71.3776340277361,
                                          71.90615967675338, 72.4700397399609] })

# %%
mansMean

# %%
plt.plot( '년도', '사망나이 평균', data=mansMean, linestyle='-', marker='o')
plt.ylim(60, 85)
plt.xlabel('년도')
plt.ylabel('사망나이 평균')
plt.show()

# %%
print(womandata2001['사망나이'].mean())
print(womandata2002['사망나이'].mean())
print(womandata2003['사망나이'].mean())
print(womandata2004['사망나이'].mean())
print(womandata2005['사망나이'].mean())
print(womandata2006['사망나이'].mean())
print(womandata2007['사망나이'].mean())
print(womandata2008['사망나이'].mean())
print(womandata2009['사망나이'].mean())
print(womandata2010['사망나이'].mean())
print(womandata2011['사망나이'].mean())
print(womandata2012['사망나이'].mean())
print(womandata2013['사망나이'].mean())
print(womandata2014['사망나이'].mean())
print(womandata2015['사망나이'].mean())
print(womandata2016['사망나이'].mean())
print(womandata2017['사망나이'].mean())
print(womandata2018['사망나이'].mean())

# %%
womansMean = df(data = {'년도' : [2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018],
                        '사망나이 평균' : [72.95158088898691, 73.53284678664244, 73.84449882128257, 74.2211958631536, 74.5840268870129,
                                     75.10323807617236, 75.3059633300888, 75.57947367358882, 75.82521519090253, 76.36149525054127,
                                     76.80266120187035, 77.46148451091659, 77.54658673687855, 77.92085514283913, 78.48411100787997,
                                     78.80643512077376, 79.56460234680574, 79.93449240328816] })

# %%
womansMean

# %%
plt.plot( '년도', '사망나이 평균', data=womansMean, linestyle='-', marker='o')
plt.ylim(60, 85)
plt.xlabel('년도')
plt.ylabel('사망나이 평균')
plt.show()
