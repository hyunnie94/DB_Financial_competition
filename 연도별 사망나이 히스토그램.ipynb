# %%
import seaborn as sns
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import scipy.stats as sp
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
# %matplotlib inline

# %%
data2013 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2013.csv", engine='python')
data2014 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2014.csv", engine="python")
data2015 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2015.csv", engine="python")
data2016 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2016.csv", engine="python")
data2017 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2017.csv", engine="python")
data2018 = pd.read_csv(r"C:\Users\digus\Desktop\db금융공모전\사망원인통계개별데이터\사망원인통계2018.csv", engine="python")

# %%
f, axes = plt.subplots(2, 3, figsize=(20, 10), sharex= True)
f.suptitle("연도별 사망나이 분포", fontsize=16)
a = sns.distplot(data2013["사망나이"], color="skyblue", ax = axes[0,0])
b = sns.distplot(data2014["사망나이"], color="hotpink", ax = axes[0,1])
c = sns.distplot(data2015["사망나이"], color="olive", ax = axes[0,2])
d = sns.distplot(data2016["사망나이"], color="gold", ax = axes[1,0])
e = sns.distplot(data2017["사망나이"], color="purple", ax = axes[1,1])
f = sns.distplot(data2018["사망나이"], color="teal", ax = axes[1,2])
a.title.set_text('2013년도')
b.title.set_text('2014년도')
c.title.set_text('2015년도')
d.title.set_text('2016년도')
e.title.set_text('2017년도')
f.title.set_text('2018년도')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
f, axes = plt.subplots(2, 3, figsize=(20, 10), sharex= True)
f.suptitle("연도별 사망나이 분포", fontsize=16)
a = sns.distplot(data2013["사망나이"], color="skyblue", ax = axes[0,0], fit=sp.norm)
b = sns.distplot(data2014["사망나이"], color="hotpink", ax = axes[0,1], fit=sp.norm)
c = sns.distplot(data2015["사망나이"], color="olive", ax = axes[0,2], fit=sp.norm)
d = sns.distplot(data2016["사망나이"], color="gold", ax = axes[1,0], fit=sp.norm)
e = sns.distplot(data2017["사망나이"], color="purple", ax = axes[1,1], fit=sp.norm)
f = sns.distplot(data2018["사망나이"], color="teal", ax = axes[1,2], fit=sp.norm)
a.title.set_text('2013년도')
b.title.set_text('2014년도')
c.title.set_text('2015년도')
d.title.set_text('2016년도')
e.title.set_text('2017년도')
f.title.set_text('2018년도')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ### 2013년도 데이터 분석

# %%
data2013_array = data2013['사망나이'].values

# %%
data2013
# Out:
#         성별  사망나이
# 0       남성     0
# 1       남성     0
# 2       남성     0
# 3       남성     0
# 4       남성     0
# 5       남성     0
# 6       남성     0
# 7       남성     0
# 8       남성     0
# 9       남성     0
# 10      남성     0
# 11      남성     0
# 12      남성     0
# 13      남성     0
# 14      남성     0
# 15      남성     0
# 16      남성     0
# 17      남성     0
# 18      남성     0
# 19      남성     0
# 20      남성     0
# 21      남성     0
# 22      남성     0
# 23      남성     0
# 24      남성     0
# 25      남성     0
# 26      남성     0
# 27      남성     0
# 28      남성     0
# 29      남성     0
# ...     ..   ...
# 266191  여성   107
# 266192  여성   107
# 266193  여성   108
# 266194  여성   108
# 266195  여성   108
# 266196  여성   108
# 266197  여성   108
# 266198  여성   108
# 266199  여성   108
# 266200  여성   108
# 266201  여성   109
# 266202  여성   109
# 266203  여성   109
# 266204  여성   109
# 266205  여성   109
# 266206  여성   110
# 266207  여성   110
# 266208  여성   110
# 266209  여성   110
# 266210  여성   110
# ...

# %%
data2013_array
# Out:
# array([  0,   0,   0, ..., 111, 111, 111], dtype=int64)

# %%
#def normalFunS(x, mu,sd):
#    a=1/(sd*np.sqrt(2*np.pi))
#    b=np.exp(-(x-mu)**2/(2*sd**2))
#    return(a*b)

# %%
#n, bins, ig = plt.hist(data2013_array, bins=50, normed = True )
#mu = np.mean(data2013_array)
#sd = np.std(data2013_array)
#plt.plot(bins, normalFunS(bins, mu, sd), linewidth=2, color='r')

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(data2013["사망나이"], ax=ax_box, color = 'skyblue')
sns.distplot(data2013["사망나이"], ax=ax_hist, fit = sp.norm, color = 'skyblue')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data2013.describe()
# Out:
#                 사망나이
# count  266221.000000
# mean       71.639356
# std        16.708598
# min         0.000000
# 25%        63.000000
# 50%        75.000000
# 75%        83.000000
# max       111.000000

# %%
x1 = np.random.normal(loc = 71.639356, scale= 16.708598, size = 266221)

# %%
sp.normaltest(x1)
# Out:
# NormaltestResult(statistic=3.7161792003456013, pvalue=0.15597031158869284)

# %%
# p- value가 0.05 이상 이므로 귀무가설을 기각 할 수 없다 -> x 가 정규분포를 따른다고 할 수 있다.

# %%
sp.describe(x1)
# Out:
# DescribeResult(nobs=266221, minmax=(-2.6711253600146563, 151.41758620234793), mean=71.7036233915842, variance=279.6373843028025, skewness=0.009044155130923975, kurtosis=-0.002860539077614188)

# %%
sp.skew(x1)  #왜도값이 0에 충분히 가깝기때문에 정규분포에 부합한다
# Out:
# 0.009044155130923975

# %%
man2013data = data2013[data2013['성별'] == '남성']

# %%
woman2013data = data2013[data2013['성별']== '여성']

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2013년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(man2013data['사망나이'], ax= axes[0] )
m1.axvline(x = 67.836939, c = 'b', ls = '--')
m1.axvline(np.percentile(man2013data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(63, 0.04, '남자 평균 67.836939', color = 'blue', size = 20)


w1 = sns.distplot(woman2013data['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 76.298582, c = 'r', ls = '--')
w1.axvline(np.percentile(woman2013data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 76.298582', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 76.298582')

# %%
np.percentile(woman2013data['사망나이'], 2)
# Out:
# 31.0

# %%
man2013data.describe()
# Out:
#                 사망나이
# count  146589.000000
# mean       67.836939
# std        16.244271
# min         0.000000
# 25%        58.000000
# 50%        71.000000
# 75%        79.000000
# max       110.000000

# %%
woman2013data.describe()
# Out:
#                 사망나이
# count  119632.000000
# mean       76.298582
# std        16.078036
# min         0.000000
# 25%        71.000000
# 50%        80.000000
# 75%        87.000000
# max       111.000000

# %% [markdown]
# ### 2014년도 데이터 분석

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(data2014["사망나이"], ax=ax_box, color = 'pink')
sns.distplot(data2014["사망나이"], ax=ax_hist, fit = sp.norm, color = 'hotpink')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data2014.describe()
# Out:
#                 사망나이
# count  267650.000000
# mean       72.099275
# std        16.574324
# min         0.000000
# 25%        63.000000
# 50%        76.000000
# 75%        84.000000
# max       111.000000

# %%
x2 = np.random.normal(loc = 72.099275, scale= 16.574324, size = 267650)

# %%
sp.normaltest(x2)
# Out:
# NormaltestResult(statistic=0.3115617378167866, pvalue=0.855746690533146)

# %%
sp.describe(x2)
# Out:
# DescribeResult(nobs=267650, minmax=(-0.6779437627082103, 144.792866002607), mean=72.04548894188791, variance=273.3086399811882, skewness=0.002579798904653314, kurtosis=-0.0012130600710666961)

# %%
sp.skew(x2)
# Out:
# 0.002579798904653314

# %%
man2014data = data2014[data2014['성별'] == '남성']
woman2014data = data2014[data2014['성별']== '여성']

# %%
man2014data.describe()
# Out:
#                 사망나이
# count  147300.000000
# mean       68.322756
# std        16.095489
# min         0.000000
# 25%        58.000000
# 50%        72.000000
# 75%        80.000000
# max       108.000000

# %%
woman2014data.describe()
# Out:
#                 사망나이
# count  120350.000000
# mean       76.721471
# std        15.969853
# min         0.000000
# 25%        72.000000
# 50%        81.000000
# 75%        87.000000
# max       111.000000

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2014년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(man2014data['사망나이'], ax= axes[0] )
m1.axvline(x = 68.322756, c = 'b', ls = '--')
m1.axvline(np.percentile(man2014data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(60, 0.037, '남자 평균 68.322756', color = 'blue', size = 20)


w1 = sns.distplot(woman2014data['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 76.721471, c = 'r', ls = '--')
w1.axvline(np.percentile(woman2014data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 76.721471', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 76.721471')

# %% [markdown]
# ### 2015년도 데이터 분석

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(data2015["사망나이"], ax=ax_box, color = 'olive')
sns.distplot(data2015["사망나이"], ax=ax_hist, fit = sp.norm, color = 'olive')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data2015.describe()
# Out:
#                 사망나이
# count  275854.000000
# mean       72.848101
# std        16.300494
# min         0.000000
# 25%        64.000000
# 50%        77.000000
# 75%        84.000000
# max       111.000000

# %%
x3 = np.random.normal(loc = 72.848101, scale= 16.300494, size = 275854)

# %%
sp.normaltest(x3)
# Out:
# NormaltestResult(statistic=0.025598078384726757, pvalue=0.9872825201784197)

# %%
sp.describe(x3)
# Out:
# DescribeResult(nobs=275854, minmax=(-3.5080727794773168, 146.30054363820136), mean=72.86112660152705, variance=264.92998753546465, skewness=-8.103034659881009e-05, kurtosis=0.0014192252157045893)

# %%
sp.skew(x3)
# Out:
# -8.103034659881009e-05

# %%
man2015data = data2015[data2015['성별'] == '남성']
woman2015data = data2015[data2015['성별']== '여성']

# %%
man2015data.describe()
# Out:
#                 사망나이
# count  150428.000000
# mean       69.055681
# std        15.896976
# min         0.000000
# 25%        59.000000
# 50%        73.000000
# 75%        80.000000
# max       107.000000

# %%
woman2015data.describe()
# Out:
#                 사망나이
# count  125426.000000
# mean       77.396489
# std        15.599770
# min         0.000000
# 25%        73.000000
# 50%        81.000000
# 75%        87.000000
# max       111.000000

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2015년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(man2015data['사망나이'], ax= axes[0] )
m1.axvline(x = 69.055681, c = 'b', ls = '--')
m1.axvline(np.percentile(man2015data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(60, 0.04, '남자 평균 69.055681', color = 'blue', size = 20)


w1 = sns.distplot(woman2015data['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 77.396489, c = 'r', ls = '--')
w1.axvline(np.percentile(woman2015data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 77.396489', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 77.396489')

# %% [markdown]
# ### 2016년도 데이터 분석

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8), sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(data2016["사망나이"], ax=ax_box, color = 'gold')
sns.distplot(data2016["사망나이"], ax=ax_hist, fit = sp.norm, color = 'gold')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data2016.describe()
# Out:
#                 사망나이
# count  280785.000000
# mean       73.304033
# std        16.146541
# min         0.000000
# 25%        65.000000
# 50%        77.000000
# 75%        85.000000
# max       111.000000

# %%
x4 = np.random.normal(loc = 73.304033, scale= 16.146541, size = 280785)

# %%
sp.normaltest(x4)
# Out:
# NormaltestResult(statistic=2.27257825705981, pvalue=0.3210080338709641)

# %%
sp.describe(x4)
# Out:
# DescribeResult(nobs=280785, minmax=(-3.9448575594121706, 145.58719758494146), mean=73.28001659597437, variance=261.1987670488574, skewness=0.004186237981288517, kurtosis=-0.011143293469682458)

# %%
sp.skew(x4)
# Out:
# 0.004186237981288517

# %%
man2016data = data2016[data2016['성별'] == '남성']
woman2016data = data2016[data2016['성별']== '여성']

# %%
man2016data.describe()
# Out:
#                 사망나이
# count  152520.000000
# mean       69.556039
# std        15.790825
# min         0.000000
# 25%        60.000000
# 50%        73.000000
# 75%        81.000000
# max       110.000000

# %%
woman2016data.describe()
# Out:
#                 사망나이
# count  128265.000000
# mean       77.760777
# std        15.416066
# min         0.000000
# 25%        73.000000
# 50%        82.000000
# 75%        88.000000
# max       111.000000

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2016년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(man2016data['사망나이'], ax= axes[0] )
m1.axvline(x = 69.556039, c = 'b', ls = '--')
m1.axvline(np.percentile(man2016data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(60, 0.04, '남자 평균 69.556039', color = 'blue', size = 20)


w1 = sns.distplot(woman2016data['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 77.760777, c = 'r', ls = '--')
w1.axvline(np.percentile(woman2016data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 77.760777', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 77.760777')

# %% [markdown]
# ### 2017년도 데이터 분석

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8),sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(data2017["사망나이"], ax=ax_box, color = 'purple')
sns.distplot(data2017["사망나이"], ax=ax_hist, fit = sp.norm, color = 'purple')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data2017.describe()
# Out:
#                 사망나이
# count  285493.000000
# mean       74.017310
# std        15.943039
# min         0.000000
# 25%        65.000000
# 50%        78.000000
# 75%        85.000000
# max       111.000000

# %%
x5 = np.random.normal(loc = 74.017310, scale= 15.943039, size = 285493)

# %%
sp.normaltest(x5)
# Out:
# NormaltestResult(statistic=1.2095249113102269, pvalue=0.5462041589396218)

# %%
sp.describe(x5)
# Out:
# DescribeResult(nobs=285493, minmax=(-1.9031763171174845, 151.41642193969426), mean=74.06823730886089, variance=253.61801963314645, skewness=0.00082323953433034, kurtosis=0.009933901161274683)

# %%
sp.skew(x5)
# Out:
# 0.00082323953433034

# %%
man2017data = data2017[data2017['성별'] == '남성']
woman2017data = data2017[data2017['성별']== '여성']

# %%
man2017data.describe()
# Out:
#                 사망나이
# count  154312.000000
# mean       70.143514
# std        15.637134
# min         0.000000
# 25%        61.000000
# 50%        74.000000
# 75%        81.000000
# max       108.000000

# %%
woman2017data.describe()
# Out:
#                 사망나이
# count  131181.000000
# mean       78.574169
# std        15.070792
# min         0.000000
# 25%        74.000000
# 50%        82.000000
# 75%        88.000000
# max       111.000000

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2017년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(man2017data['사망나이'], ax= axes[0] )
m1.axvline(x = 70.143514, c = 'b', ls = '--')
m1.axvline(np.percentile(man2017data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(60, 0.04, '남자 평균 70.143514', color = 'blue', size = 20)


w1 = sns.distplot(woman2017data['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 78.574169, c = 'r', ls = '--')
w1.axvline(np.percentile(woman2017data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 78.574169', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 78.574169')

# %% [markdown]
# ### 2018년도 데이터 분석

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8),  sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(data2018["사망나이"], ax=ax_box, color = 'teal')
sns.distplot(data2018["사망나이"], ax=ax_hist, fit = sp.norm, color = 'teal')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
data2018.describe()
# Out:
#                 사망나이
# count  298777.000000
# mean       74.463533
# std        15.783676
# min         0.000000
# 25%        66.000000
# 50%        78.000000
# 75%        85.000000
# max       111.000000

# %%
x6 = np.random.normal(loc = 74.463533, scale= 15.783676, size = 298777)

# %%
sp.normaltest(x6)
# Out:
# NormaltestResult(statistic=1.86824358454448, pvalue=0.3929307889074561)

# %%
sp.describe(x6)
# Out:
# DescribeResult(nobs=298777, minmax=(-5.985331460080246, 144.04694151906273), mean=74.46705064258688, variance=249.73209846767418, skewness=0.005986408738162437, kurtosis=0.0025348436152206055)

# %%
sp.skew(x6)
# Out:
# 0.005986408738162437

# %%
man2018data = data2018[data2018['성별'] == '남성']
woman2018data = data2018[data2018['성별']== '여성']

# %%
man2018data.describe()
# Out:
#                 사망나이
# count  161162.000000
# mean       70.687253
# std        15.438350
# min         0.000000
# 25%        61.000000
# 50%        74.000000
# 75%        82.000000
# max       108.000000

# %%
woman2018data.describe()
# Out:
#                 사망나이
# count  137615.000000
# mean       78.885964
# std        15.016470
# min         0.000000
# 25%        75.000000
# 50%        83.000000
# 75%        88.000000
# max       111.000000

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2018년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(man2018data['사망나이'], ax= axes[0] )
m1.axvline(x = 70.687253, c = 'b', ls = '--')
m1.axvline(np.percentile(man2018data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(60, 0.043, '남자 평균 70.687253', color = 'blue', size = 20)

w1 = sns.distplot(woman2018data['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 78.885964, c = 'r', ls = '--')
w1.axvline(np.percentile(woman2018data['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 78.885964', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 78.885964')

# %%
alldata = pd.concat([data2013, data2014, data2015, data2016, data2017, data2018])

# %%
manAlldata = alldata[alldata['성별'] == '남성']

# %%
womanAlldata = alldata[alldata['성별']== '여성']

# %%
manAlldata.describe()
# Out:
#                 사망나이
# count  912311.000000
# mean       69.297390
# std        15.875254
# min         0.000000
# 25%        60.000000
# 50%        73.000000
# 75%        81.000000
# max       110.000000

# %%
womanAlldata.describe()
# Out:
#                 사망나이
# count  762469.000000
# mean       77.650408
# std        15.538900
# min         0.000000
# 25%        73.000000
# 50%        82.000000
# 75%        88.000000
# max       111.000000

# %%
f, (ax_box, ax_hist) = plt.subplots(2, figsize=(20, 8),  sharex=True, gridspec_kw = {"height_ratios": (.15, .85)})

sns.boxplot(alldata["사망나이"], ax=ax_box, color = 'red')
sns.distplot(alldata["사망나이"], ax=ax_hist, fit = sp.norm, color = 'red')
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
f, axes = plt.subplots(1, 2, figsize=(20, 8), sharex=True)
f.suptitle("2013~2018년도 남녀 사망나이 비교 히스토그램", fontsize=20)

m1 = sns.distplot(manAlldata['사망나이'], ax= axes[0] )
m1.axvline(x = 69.297390, c = 'b', ls = '--')
m1.axvline(np.percentile(manAlldata['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
m1.text(60, 0.043, '남자 평균 69.297390', color = 'blue', size = 20)


w1 = sns.distplot(womanAlldata['사망나이'], ax = axes[1], color = 'salmon')
w1.axvline(x = 77.650408, c = 'r', ls = '--')
w1.axvline(np.percentile(womanAlldata['사망나이'], 2), ymax=0.25, c = 'k', ls = '--', label = '95%')
w1.text(70, 0.045, '여자 평균 77.650408', color = 'red', size = 20)
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(70, 0.045, '여자 평균 77.650408')

# %%
np.percentile(manAlldata['사망나이'], 2)
# Out:
# 28.0

# %%
fig = plt.figure(figsize=(10,6))
fig.suptitle("2013~2018년도 남녀 사망나이 비교 히스토그램", fontsize=20)
sns.distplot(manAlldata['사망나이'], label = '남성', fit=sp.norm)
sns.distplot(womanAlldata['사망나이'], label = '여성', fit=sp.norm)
fig.legend()
# Out:
# C:\Users\digus\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
